# %%
from nilearn import datasets
from nilearn.image import smooth_img
from nilearn import plotting
from nilearn import surface
import matplotlib
import numpy as np
from matplotlib import cm

my_colormap = 'Spectral'
PROJECT_DIR = '/Volumes/data/users/julie/make_parcels-julie/'

# Path to your volume of parcels
PARCEL_DIR = PROJECT_DIR + 'data/'
# Path to where you want to save the image
IMG_PATH = PROJECT_DIR + 'images/'
IMG_NAME = 'ASL_univariate_3.09.pdf'
# Full path to parcel volume with filename
PARCEL_VOL = PARCEL_DIR + 'ASL_univariate_3.09_cluster_mask_zstat1.nii.gz'

# %%
fsaverage = ('/Volumes/data/projects/blast/data/derivatives/freesurfer/fsaverage/surf/lh.pial')

# %%
result_img = smooth_img(PARCEL_VOL, fwhm=6)  
SL_texture = surface.vol_to_surf(result_img, fsaverage)

# %%
plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', SL_texture, hemi='left',
                            title='Surface left hemisphere', threshold =.05, colorbar=True,bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', SL_texture, hemi='right',
                            title='Surface right hemisphere', threshold =.05,colorbar=True, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
from nilearn import plotting
my_colormap = 'Spectral'
img_array = result_img.get_data()
img_vals = np.unique(img_array)
a_colormap = cm.get_cmap(my_colormap,len(img_vals)) 

display = plotting.plot_glass_brain(result_img, title='Speech Structure > Random',display_mode='lyrz', threshold = .5)
display.add_contours(result_img)
#my_color = matplotlib.colors.rgb2hex(temp_color[0:3])  
#display.add_contours(result_img, levels=[0.5], colors='b', linewidths=3.)

#display.add_contours(result_img, levels=[-2.8, 3.], colors=['b', 'r'], linewidths=4.)
#plotting.plot_glass_brain(SSL_rand_cluster_img, title='Speech Random > Structure', display_mode='lyrz', threshold = 'auto')

display =plotting.plot_glass_brain(result_img, title='Speech Structure > Random',display_mode='lyrz', colorbar = 'TRUE')
display.savefig('ASL_univariate_3.09.pdf')     
# Don't forget to close the display
display.close() 

#plotting.plot_glass_brain(SSL_rand_cluster_img, title='Speech Random > Structure', display_mode='lyrz', threshold = .95)

#plotting.plot_glass_brain(TSL_struct_cluster_img, title='Tone Structure > Random', display_mode='lyrz', threshold = 'auto')
#plotting.plot_glass_brain(TSL_rand_cluster_img, title='Tone Random > Structure', display_mode='lyrz', threshold = 'auto')
# Out:
# /var/folders/w1/kjlkhgfs7xl4xgm9xrkq_7m40000gn/T/ipykernel_19791/2413262350.py:3: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   img_array = result_img.get_data()

# %%
plotting.plot_glass_brain(result_img, title='Speech Structure > Random', threshold = 3.09)
plotting.plot_glass_brain(SSL_rand_cluster_img, title='Speech Random > Structure', threshold = 3.09)


plotting.plot_glass_brain(TSL_struct_cluster_img, title='Tone Structure > Random', threshold = 3.09)
plotting.plot_glass_brain(TSL_rand_cluster_img, title='Tone Random > Structure', threshold = 3.09)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w1/kjlkhgfs7xl4xgm9xrkq_7m40000gn/T/ipykernel_19791/3397996203.py in <module>
#       1 plotting.plot_glass_brain(result_img, title='Speech Structure > Random', threshold = 3.09)
# ----> 2 plotting.plot_glass_brain(SSL_rand_cluster_img, title='Speech Random > Structure', threshold = 3.09)
#       3
#       4
#       5 plotting.plot_glass_brain(TSL_struct_cluster_img, title='Tone Structure > Random', threshold = 3.09)
#
# NameError: name 'SSL_rand_cluster_img' is not defined

# %%
VSL_struct_cluster_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope1.feat/thresh_zstat1.nii.gz', fwhm=6)  
VSL_rand_cluster_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope2.feat/cluster_mask_zstat1.nii.gz', fwhm=6)  


LSL_struct_cluster_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/LSL_child_JOVE_3.09_masked.gfeat/cope2.feat/thresh_zstat1.nii.gz', fwhm=6)
LSL_rand_cluster_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/LSL_child_JOVE_3.09_masked.gfeat/cope1.feat/cluster_mask_zstat1.nii.gz', fwhm=6)

# %%
plotting.plot_glass_brain(VSL_struct_cluster_img, title='Image Structure > Random', display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(VSL_rand_cluster_img, title='Image Random > Structure', display_mode='lyrz', threshold = 'auto')


plotting.plot_glass_brain(LSL_struct_cluster_img, title='Letter Structure > Random', display_mode='lyrz', threshold = 'auto')
plotting.plot_glass_brain(LSL_rand_cluster_img, title='Letter Random > Structure', display_mode='lyrz', threshold = 'auto')

# %%
display.add_contours(result_img, levels=[-2.8, 3.], colors=['b', 'r'],
                     linewidths=4.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-989fed311a9d> in <module>()
#       1 display.add_contours(result_img, levels=[-2.8, 3.], colors=['b', 'r'],
# ----> 2                      linewidths=4.)
#
# ~/Library/Python/3.7/lib/python/site-packages/nilearn/plotting/displays.py in add_contours(self, img, threshold, filled, **kwargs)
#     736         if not filled:
#     737             threshold = None
# --> 738         self._map_show(img, type='contour', threshold=threshold, **kwargs)
#     739         if filled:
#     740             if 'levels' in kwargs:
#
# ~/Library/Python/3.7/lib/python/site-packages/nilearn/plotting/displays.py in _map_show(self, img, type, resampling_interpolation, threshold, **kwargs)
#     765         affine = img.affine
#     766         data = _utils.niimg._safe_get_data(img, ensure_finite=True)
# ...

# %%
from nilearn import plotting

plotting.plot_surf_stat_map('/Volumes/data/projects/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', SL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5,bg_map='/Volumes/data/projects/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Volumes/data/projects/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', SL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold=  1., vmax=4.5, bg_map='/Volumes/data/projects/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

#plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', SSL_texture, hemi='left', view='medial',
                          #  title='Medial left hemisphere', colorbar=True, threshold=  1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

#plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', SSL_texture, hemi='right', view='medial',
                           # title='Medial right hemisphere', colorbar=True, threshold=  1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
SSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/SpeechvRand_OHBM_vocabcovaried_2.575.gfeat/cope2.feat/thresh_zstat1.nii.gz', fwhm=6)  
SSL_texture = surface.vol_to_surf(SSL_struct_result_img, fsaverage)

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', SSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', SSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', SSL_texture, hemi='left', view='medial',
                            title='Medial left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', SSL_texture, hemi='right', view='medial',
                            title='Medial right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
VSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/VSL_child_JOVE_3.09_masked.gfeat/cope1.feat/thresh_zstat1.nii.gz', fwhm=6)  

VSL_texture = surface.vol_to_surf(VSL_struct_result_img, fsaverage)
plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', VSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', VSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', VSL_texture, hemi='left', view='medial',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', VSL_texture, hemi='right', view='medial',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
LSL_struct_result_img = smooth_img('/Users/qigroup/mnt/sylvian/blast/data/derivatives/fsl/grouplevelanalysis/LSL_child_JOVE_3.09_masked.gfeat/cope2.feat/thresh_zstat1.nii.gz', fwhm=6)  
LSL_texture = surface.vol_to_surf(LSL_struct_result_img, fsaverage)

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', LSL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', LSL_texture, hemi='right',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.orig', LSL_texture, hemi='left', view='medial',
                            title='Surface left hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/lh.sulc')

plotting.plot_surf_stat_map('/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.orig', LSL_texture, hemi='right', view='medial',
                            title='Surface right hemisphere', colorbar=True, threshold= 1., vmax=4.5, bg_map='/Users/qigroup/mnt/sylvian/blast/data/derivatives/freesurfer/fsaverage/surf/rh.sulc')

# %%
plotting.plot_glass_brain(SSL_struct_result_img, display_mode='lr', plot_abs=False,
                          title='SSL Glass brain', threshold='auto')

plotting.plot_stat_map(SSL_struct_result_img, display_mode='x', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(SSL_struct_result_img, display_mode='y', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(SSL_struct_result_img, display_mode='z', threshold=1.,
                       cut_coords=range(0, 51, 10))

# %%
plotting.plot_glass_brain(TSL_struct_cluster_img, display_mode='lr', plot_abs=False,
                          title='TSL Glass brain', threshold='auto')

plotting.plot_stat_map(TSL_struct_cluster_img, display_mode='x', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(TSL_struct_cluster_img, display_mode='y', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(TSL_struct_cluster_img, display_mode='z', threshold=1.,
                       cut_coords=range(0, 51, 10))

# %%
plotting.plot_glass_brain(VSL_struct_cluster_img, display_mode='lr', plot_abs=False,
                          title='VSL Glass brain', threshold='auto')

plotting.plot_stat_map(VSL_struct_cluster_img, display_mode='x', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(VSL_struct_cluster_img, display_mode='y', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(VSL_struct_cluster_img, display_mode='z', threshold=1.,
                       cut_coords=range(0, 51, 10))

# %%
plotting.plot_glass_brain(LSL_struct_cluster_img, display_mode='lr', plot_abs=False,
                          title='LSL Glass brain', threshold=3.09)

plotting.plot_stat_map(LSL_struct_cluster_img, display_mode='x', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(LSL_struct_cluster_img, display_mode='y', threshold=1.,
                       cut_coords=range(0, 51, 10))
plotting.plot_stat_map(LSL_struct_cluster_img, display_mode='z', threshold=1.,
                       cut_coords=range(0, 51, 10))
