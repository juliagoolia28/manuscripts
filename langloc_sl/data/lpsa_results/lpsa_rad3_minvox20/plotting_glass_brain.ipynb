# %%
from nilearn import datasets
from nilearn.image import smooth_img
from nilearn import plotting
from nilearn import surface
import matplotlib
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt

# %%
#Print all the images 

image =['1_rval.nii.gz','2_rval.nii.gz','3_rval.nii.gz','4_rval.nii.gz', 
       '5_rval.nii.gz','6_rval.nii.gz','7_rval.nii.gz','8_rval.nii.gz',
       '9_rval.nii.gz','10_rval.nii.gz','11_rval.nii.gz','12_rval.nii.gz',
       '13_rval.nii.gz','14_rval.nii.gz','15_rval.nii.gz','16_rval.nii.gz',
       '17_rval.nii.gz','18_rval.nii.gz','19_rval.nii.gz','20_rval.nii.gz',
       '21_rval.nii.gz','22_rval.nii.gz']

for i in image :
    b = "/Users/julie/Library/CloudStorage/Box-Box/My_Collaborations/fMRI_langlocssl/data/lpsa_results/lpsa_rad3_minvox20/ind_subj_maps/" + i
    DMN_gen = plotting.plot_glass_brain(b, draw_cross = True, display_mode= 'lzr', threshold = .4, colorbar=True, title = i, vmin=0,vmax=1)
    fig1 = plt.gcf()
    plt.show()
    plt.draw()
    fig1.savefig('/Users/julie/Library/CloudStorage/Box-Box/My_Collaborations/fMRI_langlocssl/data/lpsa_results/lpsa_rad3_minvox20/ind_subj_images/' + i + '_thresh.png', dpi = 100)
plt.gcf().clear()

# %%
#image =['1_zscored_fz.nii.gz','2_zscored_fz.nii.gz','3_zscored_fz.nii.gz','4_zscored_fz.nii.gz', 
 #      '5_zscored_fz.nii.gz','6_zscored_fz.nii.gz','7_zscored_fz.nii.gz','8_zscored_fz.nii.gz',
  #     '9_zscored_fz.nii.gz','10_zscored_fz.nii.gz','11_zscored_fz.nii.gz','12_zscored_fz.nii.gz',
   #    '13_zscored_fz.nii.gz','14_zscored_fz.nii.gz','15_zscored_fz.nii.gz','16_zscored_fz.nii.gz',
    #   '17_zscored_fz.nii.gz','18_zscored_fz.nii.gz','19_zscored_fz.nii.gz','20_zscored_fz.nii.gz',
     #  '21_zscored_fz.nii.gz','22_zscored_fz.nii.gz'];

image =['1_rval.nii.gz','2_rval.nii.gz','3_rval.nii.gz','4_rval.nii.gz', 
       '5_rval.nii.gz','6_rval.nii.gz','7_rval.nii.gz','8_rval.nii.gz',
       '9_rval.nii.gz','10_rval.nii.gz','11_rval.nii.gz','12_rval.nii.gz',
       '13_rval.nii.gz','14_rval.nii.gz','15_rval.nii.gz','16_rval.nii.gz',
       '17_rval.nii.gz','18_rval.nii.gz','19_rval.nii.gz','20_rval.nii.gz',
       '21_rval.nii.gz','22_rval.nii.gz']

# %%
fsaverage = ('lh.pial')

for i in image :
    b = "/Users/julie/Library/CloudStorage/Box-Box/My_Collaborations/fMRI_langlocssl/data/lpsa_results/lpsa_rad3_minvox20/ind_subj_maps/" + i
    result_img = smooth_img(b, fwhm=6)  
    SL_texture = surface.vol_to_surf(result_img, fsaverage)
    plotting.plot_surf_stat_map(fsaverage, SL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True,bg_map='lh.sulc')
# Out:
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/plotting/surf_plotting.py:465: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figure = plt.figure(figsize=figsize)
# Error in callback <function flush_figures at 0x1246b89d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ...

# %%
from nilearn import plotting
from nilearn import surface

fsaverage = ('lh.inflated')

for i in image :
    b = "/Users/julie/Library/CloudStorage/Box-Box/My_Collaborations/fMRI_langlocssl/data/lpsa_results/lpsa_rad3_minvox20/ind_subj_maps/" + i
    result_img = smooth_img(b, fwhm=6)  
    SL_texture = surface.vol_to_surf(result_img, fsaverage)
    plotting.plot_surf_stat_map(fsaverage, SL_texture, hemi='left',
                            title='Surface left hemisphere', colorbar=True,bg_map='lh.sulc')
# Out:
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
#   texture = np.nanmean(all_samples, axis=2)
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
#   texture = np.nanmean(all_samples, axis=2)
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
#   texture = np.nanmean(all_samples, axis=2)
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
#   texture = np.nanmean(all_samples, axis=2)
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
#   texture = np.nanmean(all_samples, axis=2)
# /Users/julie/Library/Python/3.8/lib/python/site-packages/nilearn/surface/surface.py:464: RuntimeWarning: Mean of empty slice
# ...
